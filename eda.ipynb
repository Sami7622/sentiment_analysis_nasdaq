# %%
! pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./dogo_venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 812.9 kB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 443.6 kB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 832.2 kB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
! pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./dogo_venv/lib/python3.13/site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in ./dogo_venv/lib/python3.13/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./dogo_venv/lib/python3.13/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./dogo_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./dogo_venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./dogo_venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in ./dogo_venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("/Users/sami/Desktop/Projects/Dogo/raw_dataset.csv")
df.head(20)
# Out:
#                                                    id    datetime ticker  \
# 0   db221630f08d9064b6539534cc9957ecd7ba2a626927c7...  2023-06-29   ALGT
# 1   bb7e1725949a7254ae18e8d149c3c19af050c0ac05f18f...  2023-04-27    AIT
# 2   bb7e1725949a7254ae18e8d149c3c19af050c0ac05f18f...  2023-04-27    NPO
# 3   a49c53ef44092946950dfb3f33852c9ef07d7c7dc6c1ea...  2023-03-06    ARI
# 4   a49c53ef44092946950dfb3f33852c9ef07d7c7dc6c1ea...  2023-03-06    SAN
# 5   be4f5174307cd0f3309ee931ab4ec4fc2451af056769ca...  2023-11-09   MRVI
# 6   29bea2bb15df75a10fd940c2dc705d21d4c413fb45c17a...  2023-03-22    DHT
# 7   ed906d34b6032bbd31d6c0b730fb056afbaafaed308da2...  2023-07-28   META
# 8   1c070a57209ddd5f8fdf4569ef8eb486f4977677a32b12...  2023-05-17  CMCSA
# 9   1c070a57209ddd5f8fdf4569ef8eb486f4977677a32b12...  2023-05-17    DIS
# 10  1c070a57209ddd5f8fdf4569ef8eb486f4977677a32b12...  2023-05-17   NFLX
# 11  1c070a57209ddd5f8fdf4569ef8eb486f4977677a32b12...  2023-05-17    WBD
# 12  3852eed3ea95a2d2532a29d01f9b098a08977a02796b2c...  2023-01-20   SRPT
# 13  8e5fbe84dfaa5a54a7202b3f2ef9d998c85c704966fbb3...  2023-12-26   ATMU
# 14  8e5fbe84dfaa5a54a7202b3f2ef9d998c85c704966fbb3...  2023-12-26  DTEGY
# 15  fe08d133ba353359ee01593e9cefe8fbdd9f8cc79de43c...  2023-05-04   CLDX
# 16  fe08d133ba353359ee01593e9cefe8fbdd9f8cc79de43c...  2023-05-04   TFFP
# 17  3f230e1cc30ef45e7ed503b6d95a7f90ce8248acded424...  2023-05-08    AAL
# 18  2f2165f18f0c7db43ff07f7ce747fecb8a0fa102e897e2...  2023-08-09   BLBD
# 19  2f2165f18f0c7db43ff07f7ce747fecb8a0fa102e897e2...  2023-08-09   ZEVY
#
#                                           description sentiment
# 0   Allegiant Travel (ALGT) is a fast-moving stock...  positive
# 1   Applied Industrial Technologies (AIT) reported...  positive
# 2   Applied Industrial Technologies (AIT) reported...   neutral
# 3   Apollo Commercial Real Estate Finance, Inc. (A...  positive
# 4   Apollo Commercial Real Estate Finance, Inc. (A...   neutral
# 5   Maravai LifeSciences, a global provider of lif...  positive
# 6   DHT Holdings, an independent oil tanker compan...   neutral
# 7   Meta Platforms reported outstanding earnings f...  positive
# 8   The entertainment industry has faced challenge...  positive
# 9   The entertainment industry has faced challenge...   neutral
# 10  The entertainment industry has faced challenge...   neutral
# 11  The entertainment industry has faced challenge...   neutral
# 12  9 analysts have provided 12-month price target...  positive
# 13  The article highlights three stocks with a Zac...  positive
# 14  The article highlights three stocks with a Zac...  positive
# 15  Celldex Therapeutics reported a quarterly loss...   neutral
# 16  Celldex Therapeutics reported a quarterly loss...   neutral
# 17  JP Morgan has upgraded its rating of American ...  positive
# 18  Blue Bird reported better-than-expected Q4 ear...  positive
# 19  Blue Bird reported better-than-expected Q4 ear...   neutral

# %%
df.columns
# Out:
# Index(['id', 'datetime', 'ticker', 'description', 'sentiment'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13392 entries, 0 to 13391
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           13392 non-null  object
#  1   datetime     13392 non-null  object
#  2   ticker       13392 non-null  object
#  3   description  13392 non-null  object
#  4   sentiment    13390 non-null  object
# dtypes: object(5)
# memory usage: 523.3+ KB

# %%
df.describe()
# Out:
#                                                        id    datetime ticker  \
# count                                               13392       13392  13392
# unique                                               5548         348   3702
# top     da1c8daa7789a1ac5aca8ed60ecf1c3d70472f6804230c...  2023-01-26   AMZN
# freq                                                   56         129    135
#
#                                               description sentiment
# count                                               13392     13390
# unique                                              10507         5
# top     Coinbase Global (COIN) is set to report Q4 202...  positive
# freq                                                   25      8296

# %%
df.isnull().sum()
# Out:
# id             0
# datetime       0
# ticker         0
# description    0
# sentiment      2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# drop the rows with null values
df = df.dropna()

# %%
df.shape
# Out:
# (13390, 5)

# %%
df.head()
# Out:
#                                                   id    datetime ticker  \
# 0  db221630f08d9064b6539534cc9957ecd7ba2a626927c7...  2023-06-29   ALGT
# 1  bb7e1725949a7254ae18e8d149c3c19af050c0ac05f18f...  2023-04-27    AIT
# 2  bb7e1725949a7254ae18e8d149c3c19af050c0ac05f18f...  2023-04-27    NPO
# 3  a49c53ef44092946950dfb3f33852c9ef07d7c7dc6c1ea...  2023-03-06    ARI
# 4  a49c53ef44092946950dfb3f33852c9ef07d7c7dc6c1ea...  2023-03-06    SAN
#
#                                          description sentiment
# 0  Allegiant Travel (ALGT) is a fast-moving stock...  positive
# 1  Applied Industrial Technologies (AIT) reported...  positive
# 2  Applied Industrial Technologies (AIT) reported...   neutral
# 3  Apollo Commercial Real Estate Finance, Inc. (A...  positive
# 4  Apollo Commercial Real Estate Finance, Inc. (A...   neutral

# %%
df.columns
# Out:
# Index(['id', 'datetime', 'ticker', 'description', 'sentiment'], dtype='object')

# %%
df = df.drop(columns=["id"])

# %%
df.isnull().sum()
# Out:
# datetime       0
# ticker         0
# description    0
# sentiment      0
# dtype: int64

# %%
df.shape
# Out:
# (13390, 4)

# %%
df.head(5)
# Out:
#      datetime ticker                                        description  \
# 0  2023-06-29   ALGT  Allegiant Travel (ALGT) is a fast-moving stock...
# 1  2023-04-27    AIT  Applied Industrial Technologies (AIT) reported...
# 2  2023-04-27    NPO  Applied Industrial Technologies (AIT) reported...
# 3  2023-03-06    ARI  Apollo Commercial Real Estate Finance, Inc. (A...
# 4  2023-03-06    SAN  Apollo Commercial Real Estate Finance, Inc. (A...
#
#   sentiment
# 0  positive
# 1  positive
# 2   neutral
# 3  positive
# 4   neutral

# %%
avl_tickers = df["ticker"].unique()
len(avl_tickers)
# Out:
# 3702

# %%
sent_map = {'positive': 0, 'negative': 1, 'neutral': 2}
df['label'] = df['sentiment'].map(sent_map)

# %%
df.head(5)
# Out:
#      datetime ticker                                        description  \
# 0  2023-06-29   ALGT  Allegiant Travel (ALGT) is a fast-moving stock...
# 1  2023-04-27    AIT  Applied Industrial Technologies (AIT) reported...
# 2  2023-04-27    NPO  Applied Industrial Technologies (AIT) reported...
# 3  2023-03-06    ARI  Apollo Commercial Real Estate Finance, Inc. (A...
# 4  2023-03-06    SAN  Apollo Commercial Real Estate Finance, Inc. (A...
#
#   sentiment  label
# 0  positive    0.0
# 1  positive    0.0
# 2   neutral    2.0
# 3  positive    0.0
# 4   neutral    2.0

# %%
df = df.drop(columns=["sentiment"])

# %%
df['description'] = df['description'].str.lower()

# %%
df['description'][:5]
# Out:
# 0    allegiant travel (algt) is a fast-moving stock...
# 1    applied industrial technologies (ait) reported...
# 2    applied industrial technologies (ait) reported...
# 3    apollo commercial real estate finance, inc. (a...
# 4    apollo commercial real estate finance, inc. (a...
# Name: description, dtype: object

# %%
# Install required packages
! pip install transformers torch xgboost optuna scikit-learn

# %%
import re
import string
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import xgboost as xgb
import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances
import warnings
warnings.filterwarnings('ignore')

# %%
# Text cleaning function
def clean_text(text):
    """
    Clean text by removing URLs, special characters, extra spaces, etc.
    """
    if pd.isna(text):
        return ""
    
    # Convert to string if not already
    text = str(text)
    
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    
    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)
    
    # Remove special characters but keep spaces and basic punctuation
    text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text)
    
    # Strip leading/trailing whitespace
    text = text.strip()
    
    return text

# Apply text cleaning
df['cleaned_description'] = df['description'].apply(clean_text)

# Remove rows with empty cleaned descriptions
df = df[df['cleaned_description'].str.len() > 0]

print(f"Shape after cleaning: {df.shape}")
print(f"\nSample cleaned text:")
print(df['cleaned_description'].head(3))

# %%
# Load BERT tokenizer and model
print("Loading BERT tokenizer and model...")
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
print(f"Using device: {device}")

# %%
# Function to get BERT embeddings
def get_bert_embeddings(texts, batch_size=32, max_length=128):
    """
    Get BERT embeddings for a list of texts
    """
    embeddings = []
    
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        
        # Tokenize
        encoded = tokenizer(
            batch_texts,
            padding=True,
            truncation=True,
            max_length=max_length,
            return_tensors="pt"
        )
        
        # Move to device
        encoded = {k: v.to(device) for k, v in encoded.items()}
        
        # Get embeddings (use [CLS] token embedding)
        with torch.no_grad():
            outputs = model(**encoded)
            # Use mean pooling of all token embeddings
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
        
        embeddings.append(batch_embeddings)
        
        if (i // batch_size + 1) % 10 == 0:
            print(f"Processed {i + len(batch_texts)}/{len(texts)} texts...")
    
    return np.vstack(embeddings)

# Extract BERT embeddings
print("Extracting BERT embeddings...")
texts = df['cleaned_description'].tolist()
X_bert = get_bert_embeddings(texts)
y = df['label'].values

print(f"BERT embeddings shape: {X_bert.shape}")
print(f"Labels shape: {y.shape}")

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_bert, y, test_size=0.2, random_state=42, stratify=y
)

print(f"Train set shape: {X_train.shape}")
print(f"Test set shape: {X_test.shape}")
print(f"\nTrain label distribution:")
print(pd.Series(y_train).value_counts().sort_index())
print(f"\nTest label distribution:")
print(pd.Series(y_test).value_counts().sort_index())

# %%
# Train baseline XGBoost model
print("Training baseline XGBoost model...")
baseline_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    random_state=42,
    n_jobs=-1,
    eval_metric='mlogloss'
)

baseline_model.fit(X_train, y_train)

# Evaluate baseline model
y_pred_baseline = baseline_model.predict(X_test)
baseline_accuracy = accuracy_score(y_test, y_pred_baseline)

print(f"\nBaseline XGBoost Accuracy: {baseline_accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_baseline, target_names=['positive', 'negative', 'neutral']))

# %%
# Optuna hyperparameter optimization
def objective(trial):
    """
    Objective function for Optuna optimization
    """
    params = {
        'objective': 'multi:softprob',
        'num_class': 3,
        'eval_metric': 'mlogloss',
        'random_state': 42,
        'n_jobs': -1,
        'tree_method': 'hist',
        
        # Hyperparameters to tune
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Create model with suggested parameters
    model = xgb.XGBClassifier(**params)
    
    # Train model
    model.fit(X_train, y_train)
    
    # Predict and calculate accuracy
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    
    return accuracy

# Run Optuna optimization
print("Starting Optuna hyperparameter optimization...")
print("This may take a while...\n")

study = optuna.create_study(direction='maximize', study_name='xgboost_optimization')
study.optimize(objective, n_trials=50, show_progress_bar=True)

print("\n" + "="*50)
print("Optimization Complete!")
print("="*50)
print(f"\nBest trial:")
trial = study.best_trial
print(f"  Value (Accuracy): {trial.value:.4f}")
print(f"\n  Params:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# %%
# Train final model with best parameters
print("Training final XGBoost model with best parameters...")

best_params = study.best_params.copy()
best_params.update({
    'objective': 'multi:softprob',
    'num_class': 3,
    'eval_metric': 'mlogloss',
    'random_state': 42,
    'n_jobs': -1,
    'tree_method': 'hist'
})

final_model = xgb.XGBClassifier(**best_params)
final_model.fit(X_train, y_train)

# Evaluate final model
y_pred_final = final_model.predict(X_test)
final_accuracy = accuracy_score(y_test, y_pred_final)

print(f"\nFinal XGBoost Accuracy: {final_accuracy:.4f}")
print(f"Improvement over baseline: {final_accuracy - baseline_accuracy:.4f} ({((final_accuracy - baseline_accuracy) / baseline_accuracy * 100):.2f}%)")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_final, target_names=['positive', 'negative', 'neutral']))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_final))

# %%
# Visualize Optuna optimization results
try:
    fig1 = plot_optimization_history(study)
    fig1.show()
    
    fig2 = plot_param_importances(study)
    fig2.show()
except:
    print("Could not display Optuna visualizations. You can view them in Optuna dashboard if needed.")
